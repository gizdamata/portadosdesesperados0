# %%
Giovanna da Mata S. M. P. - 216890

# %%
from random import randint

porta1 = 0
porta2 = 0
porta3 = 0
k = 2
i = 2

while k == 2:
  porta1 = randint(0,1)
  porta2 = randint(0,1)

  if porta1 != porta2:
    porta3 = 0
    k = 0

  elif porta1 == porta2:
    porta3 = 1
    k = 0
  
  if porta1 == porta2 == 1 or porta1 ==  porta3 == 1 or porta2 == porta3 == 1:
    k = 2
 

x = int(input("Digite o número da porta escolhida: "))


while i == 2:
  if x == 1:
    if porta2 == 0:
      print("A porta 2 é aberta... Ela não tem o prêmio!")
      i = 0
    elif porta3 == 0:
      print("A porta 3 é aberta... Ela não tem o prêmio!")
      i = 0

  if x == 2:
    if porta1 == 0:
      print("A porta 1 é aberta... Ela não tem o prêmio!")
      i = 0
    elif porta3 == 0:
      print("A porta 3 é aberta... Ela não tem o prêmio!")
      i = 0
  
  if x == 3:
    if porta1 == 0:
      print("A porta 1 é aberta... Ela não tem o prêmio!")
      i = 0
    elif porta2 == 0:
      print("A porta 2 é aberta... Ela não tem o prêmio!")
      i = 0


y = input("Deseja trocar sua porta pela outra fechada?(Digite Sim ou Não) ")

if y == "Não":
  if x == 1:
    if porta1 == 0:
      print("O prêmio não está nessa porta! Você perdeu.")
    elif porta1 == 1:
      print("O prêmio está nessa porta! Você venceu!")

  if x == 2:
    if porta2 == 0:
      print("O prêmio não está nessa porta! Você perdeu.")
    elif porta2 == 1:
      print("O prêmio está nessa porta! Você venceu!")

  if x == 3:
    if porta3 == 0:
      print("O prêmio não está nessa porta! Você perdeu.")
    elif porta3 == 1:
      print("O prêmio está nessa porta! Você venceu!")

elif y == "Sim":
  z = int(input("Digite o número da outra porta fechada: "))
  if z == 1:
    if porta1 == 0:
      print("O prêmio não está nessa porta! Você perdeu.")
    elif porta1 == 1:
      print("O prêmio está nessa porta! Você venceu!")

  if z == 2:
    if porta2 == 0:
      print("O prêmio não está nessa porta! Você perdeu.")
    elif porta2 == 1:
      print("O prêmio está nessa porta! Você venceu!")

  if z == 3:
    if porta3 == 0:
      print("O prêmio não está nessa porta! Você perdeu.")
    elif porta3 == 1:
      print("O prêmio está nessa porta! Você venceu!")
